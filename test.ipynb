# %%
from dateutil import parser

# %%
date = '2023-04-11 07:34:58'

print(type(date))
# Out:
# <class 'str'>

# %%
date = parser.parse(date)

# %%
print((date))
# Out:
# 2023-04-11 07:34:58

# %%
date.year
# Out:
# 2023

# %%
date.day
# Out:
# 11

# %%
date.month
# Out:
# 4

# %%
date.weekday()
# Out:
# 1

# %%
date.hour
# Out:
# 7

# %%
date.minute
# Out:
# 34

# %%
date.second
# Out:
# 58

# %%
date2 = '2023-04-10 19:13:36'

date2 = parser.parse(date2)

# %%
date2.hour
# Out:
# 19

# %%
def extract_date(date):
    date = parser.parse(date)
    return (date.year, date.month, date.day, date.weekday(), date.hour, date.minute, date.second)

# %%
extract_date('2023-04-10 19:13:36')
# Out:
# (2023, 4, 10, 0, 19, 13, 36)

# %%
import pandas as pd
import numpy as np
import mysql.connector

# %%
db = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    password='root'

)

mycursor = db.cursor()

# %%
querry = 'SELECT * FROM mtracker.transaction_type;'

df = pd.read_sql(querry, db, parse_dates = True)
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df
# Out:
#      Receipt No.      Completion Time  \
# 0     RDB7VLX827  2023-04-11 07:34:58
# 1     RDB0VIRHTI  2023-04-11 06:17:55
# 2     RDA8V2XOWG  2023-04-10 20:28:58
# 3     RDA4V2RODM  2023-04-10 20:27:28
# 4     RDA1V266WT  2023-04-10 20:22:35
# ...          ...                  ...
# 1131  RA10GI49RQ  2023-01-01 10:02:33
# 1132  RA10GI49RQ  2023-01-01 10:02:33
# 1133  RA10GI49RQ  2023-01-01 10:02:33
# 1134  RA10GI2APY  2023-01-01 10:01:48
# 1135  RA12GI1SRW  2023-01-01 10:01:48
#
#                                                 Details Transaction Status  \
# 0            Merchant Payment to 7603071 - EUNICE RURII          Completed
# 1     Pay Bill Online to 888880 - KPLC PREPAID Acc. ...          Completed
# 2        Customer Transfer to - 07******179 Peter Osodo          Completed
# 3           Merchant Payment to 7569854 - SAMUEL NDUNGU          Completed
# 4           Merchant Payment to 7441768 - JAWS BUTCHERY          Completed
# ...

# %%
dates = df['Completion Time'].apply(lambda x: extract_date(x)).values

# %%
year = [i[0] for i in dates]
month = [i[1] for i in dates]
date = [i[2] for i in dates]
weekday = [i[3] for i in dates]
hour = [i[4] for i in dates]
minute = [i[5] for i in dates]
second = [i[6] for i in dates]

# %%
date
trasaction_day = []
datex = date[0]
d = 1

for i in date:
    if i == datex:
        trasaction_day.append(d)
    else:
        datex = i
        d+= 1
        trasaction_day.append(d)
# Out:
# 1136
# 97

# %%
df.insert(2, 'year', year)
df.insert(3, 'month', month)
df.insert(4, 'date', date)
df.insert(5, 'weekday', weekday)
df.insert(6, 'hour', hour)
df.insert(7, 'minute', minute)
df.insert(8, 'second', second)

# %%
df.head(40)
# Out:
#    Receipt No.      Completion Time  year  month  date  weekday  hour  minute  \
# 0   RDB7VLX827  2023-04-11 07:34:58  2023      4    11        1     7      34
# 1   RDB0VIRHTI  2023-04-11 06:17:55  2023      4    11        1     6      17
# 2   RDA8V2XOWG  2023-04-10 20:28:58  2023      4    10        0    20      28
# 3   RDA4V2RODM  2023-04-10 20:27:28  2023      4    10        0    20      27
# 4   RDA1V266WT  2023-04-10 20:22:35  2023      4    10        0    20      22
# 5   RDA3V11ZWX  2023-04-10 20:13:36  2023      4    10        0    20      13
# 6   RDA4V0W7G8  2023-04-10 20:12:19  2023      4    10        0    20      12
# 7   RDA1V0LT5P  2023-04-10 20:10:06  2023      4    10        0    20      10
# 8   RDA0V0824U  2023-04-10 20:07:17  2023      4    10        0    20       7
# 9   RDA9UZI3MB  2023-04-10 20:01:50  2023      4    10        0    20       1
# 10  RDA6UW2UUC  2023-04-10 19:37:35  2023      4    10        0    19      37
# ...

# %%
#######################################################

# %%
x = 'Customer Withdrawal At Agent Till 087443 - Dotnet Systems Amkar Shop Juja Agg'
index = x.find(' - ')+3
name =  x[index:].strip().upper()
    
name
# Out:
# 'DOTNET SYSTEMS AMKAR SHOP JUJA AGG'

# %%
df
# Out:
#      Receipt No.      Completion Time  year  month  date  weekday  hour  \
# 0     RDB7VLX827  2023-04-11 07:34:58  2023      4    11        1     7
# 1     RDB0VIRHTI  2023-04-11 06:17:55  2023      4    11        1     6
# 2     RDA8V2XOWG  2023-04-10 20:28:58  2023      4    10        0    20
# 3     RDA4V2RODM  2023-04-10 20:27:28  2023      4    10        0    20
# 4     RDA1V266WT  2023-04-10 20:22:35  2023      4    10        0    20
# ...          ...                  ...   ...    ...   ...      ...   ...
# 1131  RA10GI49RQ  2023-01-01 10:02:33  2023      1     1        6    10
# 1132  RA10GI49RQ  2023-01-01 10:02:33  2023      1     1        6    10
# 1133  RA10GI49RQ  2023-01-01 10:02:33  2023      1     1        6    10
# 1134  RA10GI2APY  2023-01-01 10:01:48  2023      1     1        6    10
# 1135  RA12GI1SRW  2023-01-01 10:01:48  2023      1     1        6    10
#
#       minute  second                                            Details  \
# ...

# %%
my_list = [1, 2, 3, 4, 5]
my_list.reverse()
print(my_list)
# Out:
# [5, 4, 3, 2, 1]
